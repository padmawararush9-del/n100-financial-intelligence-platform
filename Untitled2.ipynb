# %%
from src.analytics.ratios import *

print(
    net_profit_margin(
        200,
        1000
    )
)

print(
    roe(
        200,
        100,
        900
    )
)

print(
    roa(
        200,
        5000
    )
)
# Out:
# 20.0
# 20.0
# 4.0
